# %%
#load libraries 
import pandas as pd
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load datasets
Dfwnred = pd.read_csv('winequality-red.csv')

# %%
#Dfwnered[['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'] = Dfwinred["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"]] = Dfwnred[""fixed acidity";"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality""].apply(lambda x: pd.Series(str(x).split(";")))

# %%
df1 = pd.DataFrame(Dfwnred)
df1
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %%
df1.columns
# Out:
# Index(['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'], dtype='object')

# %%
df1.rename(columns = {'fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"':'COLUMNS'}, inplace = True)
df1
# Out:
#                                                 COLUMNS
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %%
df1[["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"]] = df1['COLUMNS'].str.split(';', expand=True)
df1
# Out:
#                                                 COLUMNS fixed acidity  \
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5           7.4
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5           7.8
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...           7.8
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...          11.2
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5           7.4
# ...                                                 ...           ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5           6.2
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...           5.9
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...           6.3
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...           5.9
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...             6
#
#      volatile acidity citric acid residual sugar chlorides  \
# 0                 0.7           0            1.9     0.076
# ...

# %%
df1 = df1.drop(['COLUMNS'], axis=1)

# %%
df1['fixed acidity'] = df1['fixed acidity'].astype(float)
df1['volatile acidity'] = df1['volatile acidity'].astype(float)
df1['citric acid'] = df1['citric acid'].astype(float)
df1['residual sugar'] = df1['residual sugar'].astype(float)
df1['chlorides'] = df1['chlorides'].astype(float)
df1['free sulfur dioxide'] = df1['free sulfur dioxide'].astype(float)
df1['total sulfur dioxide'] = df1['total sulfur dioxide'].astype(float)
df1['density'] = df1['density'].astype(float)
df1['pH'] = df1['pH'].astype(float)
df1['sulphates'] = df1['sulphates'].astype(float)
df1['alcohol'] = df1['alcohol'].astype(float)
df1['quality'] = df1['quality'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # Hypothesis
# * Null Hypothesis :  Wines with a higher quality rating have a higher median alcohol content than wines with a lower quality rating
# * Alternative Hypothesis : Wines with a higher quality rating do not have a higher median alcohol content than wines with a lower quality rating

# %%
quality_medians = df1.groupby('quality')['alcohol'].median()
print(quality_medians)
# Out:
# quality
# 3.0     9.925
# 4.0    10.000
# 5.0     9.700
# 6.0    10.500
# 7.0    11.500
# 8.0    12.150
# Name: alcohol, dtype: float64

# %%
from scipy.stats import mannwhitneyu

high_quality = df1[df1['quality'] >= 7]['alcohol']
low_quality = df1[df1['quality'] < 7]['alcohol']

stat, p = mannwhitneyu(high_quality, low_quality, alternative='greater')
alpha = 0.05
print('Mann-Whitney U test')
print(f'p-value: {p:.4f}')
if p < alpha:
    print('Reject null hypothesis')
else:
    print('Fail to reject null hypothesis ')
# Out:
# Mann-Whitney U test
# p-value: 0.0000
# Reject null hypothesis
